# %%
# !pip install ultralytics opencv-python matplotlib

from ultralytics import YOLO
import os
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="O4wk1qfuupDyYRaSAYuZ")
project = rf.workspace("test-e86rv").project("suspicious-behavior-ztrya")
version = project.version(15)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 46.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 125.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Suspicious-Behavior-15 in yolov11:: 100%|██████████| 3386/3386 [00:00<00:00, 11014.34it/s]

# %%
yaml_content = """
path: /content/Suspicious-Behavior-15
train: /content/Suspicious-Behavior-15/train/images
val: /content/Suspicious-Behavior-15/valid/images
test: /content/Suspicious-Behavior-15/test/images

nc: 4
names: ['abnormal action', 'covered', 'person', 'weapon']
"""

with open("dataset.yaml", "w") as f:
    f.write(yaml_content)

# %%
model = YOLO("yolo11n.pt")

results = model.train(
    data="dataset.yaml",
    epochs=50,
    imgsz=512,
    batch=16,
    freeze=10,
    name="yolo11-custom"
)
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 296.0±112.6 MB/s, size: 6.1 KB)
# val: Scanning /content/Suspicious-Behavior-15/valid/labels.cache... 158 images, 2 backgrounds, 0 corrupt: 100%|██████████| 158/158 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  4.79it/s]
#                    all        158        503      0.778      0.753      0.794      0.512
#        abnormal action         94        103      0.761      0.932      0.914      0.666
#                covered        108        137      0.832      0.833      0.862      0.565
#                 person         86        200      0.777       0.79      0.862      0.602
# ...

# %%
# Evaluar el modelo en el conjunto test
metrics_test = model.val(data="dataset.yaml", split="test")
print(metrics_test)
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 335.0±152.7 MB/s, size: 9.0 KB)
# val: Scanning /content/Suspicious-Behavior-15/test/labels... 2 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2/2 [00:00<00:00, 2332.11it/s]
# val: New cache created: /content/Suspicious-Behavior-15/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  9.02it/s]
#                    all          2          6      0.646      0.667      0.697      0.506
#        abnormal action          2          2      0.955          1      0.995      0.895
#                covered          2          2      0.982          1      0.995      0.602
#                 weapon          2          2          0          0     0.0995     0.0199
# Speed: 0.3ms preprocess, 43.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# ...

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/yolo11-custom23/ (stored 0%)
#   adding: runs/detect/yolo11-custom23/P_curve.png (deflated 15%)
#   adding: runs/detect/yolo11-custom23/val_batch0_pred.jpg (deflated 22%)
#   adding: runs/detect/yolo11-custom23/confusion_matrix.png (deflated 31%)
#   adding: runs/detect/yolo11-custom23/F1_curve.png (deflated 13%)
#   adding: runs/detect/yolo11-custom23/val_batch0_labels.jpg (deflated 21%)
#   adding: runs/detect/yolo11-custom23/PR_curve.png (deflated 23%)
#   adding: runs/detect/yolo11-custom23/confusion_matrix_normalized.png (deflated 29%)
#   adding: runs/detect/yolo11-custom23/R_curve.png (deflated 18%)
#   adding: runs/detect/yolo11-custom/ (stored 0%)
#   adding: runs/detect/yolo11-custom/weights/ (stored 0%)
#   adding: runs/detect/yolo11-custom/args.yaml (deflated 52%)
#   adding: runs/detect/yolo11-custom22/ (stored 0%)
#   adding: runs/detect/yolo11-custom22/P_curve.png (deflated 10%)
# ...

# %%
from google.colab import files
files.download("runs.zip")
